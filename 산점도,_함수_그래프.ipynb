# %% [markdown]
# <a href="https://colab.research.google.com/github/yunseo4401/EDA/blob/main/%EC%82%B0%EC%A0%90%EB%8F%84%2C_%ED%95%A8%EC%88%98_%EA%B7%B8%EB%9E%98%ED%94%84.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt

iris=load_iris()
iris=pd.DataFrame(iris.data,columns=iris.feature_names)
iris['Class']=load_iris().target
iris['Class']=iris['Class'].map({0:'Setosa',1:'Versicolour',2:'Virginica'})

# %%
iris
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#          Class
# 0       Setosa
# 1       Setosa
# 2       Setosa
# 3       Setosa
# 4       Setosa
# ..         ...
# 145  Virginica
# 146  Virginica
# 147  Virginica
# 148  Virginica
# 149  Virginica
#
# [150 rows x 5 columns]

# %%
plt.title('iris scatter')
plt.xlabel('sepal length(cm)')
plt.ylabel('sepal width (cm)')

plt.scatter(x=iris['sepal length (cm)'], y=iris['sepal width (cm)'],alpha=0.5)
plt.show()

# %%
import seaborn as sns
sns.scatterplot(x='sepal length (cm)',y='sepal width (cm)',data=iris,hue='Class',style='Class') #클래스 별 
plt.show()

# %%
#함수식 그래프 
def linear_func(x):
  return 2*x + 1

x=iris['sepal length (cm)']
plt.plot(x,linear_func(x),C='#789395')
plt.show()

# %%
#회귀선 그래프 
import numpy as np
x,y=iris['sepal length (cm)'],iris['petal length (cm)']
b1,b0=np.polyfit(x,y,1)
#numpy.polyfit() 함수는 x값,y값을 입력받아 최소제곱 다항식에 적합한다. 차수+1개가 출력되고, 가장 높은 차원의 계수부터 순서대로 출력 
plt.scatter(x=x,y=y,alpha=0.5)
plt.plot(x,b1*x+b0,color='red')
plt.show()

# %%
#2차이상의 그래프를 그리는 경우는 x값에 대하여 정렬할 필요가 있음 
iris2=iris.sort_values(by='sepal length (cm)')
x,y=iris2['sepal length (cm)'],iris2['petal length (cm)']
b2,b1,b0=np.polyfit(x,y,2)
plt.scatter(x=x,y=y,alpha=0.5)
plt.plot(x,b0+b1*x + b2*x**2,color='red')
plt.show()

# %%
#꺾은선 그래프 
#시간의 변화에 따라 값변화할때 유용한 그래프 
#x값에 대한 정렬이 필요함 
iris2=iris.sort_values(by='sepal length (cm)')
plt.plot('sepal length (cm)','petal length (cm)',data=iris2)
plt.show()

# %%
#카테고리 별 
plt.plot('sepal length (cm)','petal length (cm)',data=iris2.loc[iris2['Class']=='Setosa'])
plt.plot('sepal length (cm)','petal length (cm)',data=iris2.loc[iris2['Class']=='Versicolour'])
plt.plot('sepal length (cm)','petal length (cm)',data=iris2.loc[iris2['Class']=='Virginica'])
plt.legend(iris2.Class.unique())
plt.show()
